# %%
x=[20,30]
y=x
y.append(10)

print(id(x), id(y))
x 

1926651948992== 1926651948992
# Out:
# 1926651948992 1926651948992
# [20, 30, 10]

# %%
a=[10,20]
b=[10,20]
a==b
print(id(a) , id (b))
1926651943808 == 1926651947712
# Out:
# 1926651948672 1926651940736
# False

# %%
dic={
    "Name ": "Raheem",
    "age ": 21
}

for key , val  in enumerate(dic):
    print(f"key : {key} Value: {val}")

for key ,values in dic.items():
    print(f" key :{key} values: {values}")
# Out:
# key : 0 Value: Name
# key : 1 Value: age

# %%
logs=[101,102,102,103,102]
unqiue_user=set(logs)
unqiue_use
# Out:
# {101, 102, 103}

# %%
#symatic difference 
s1={1,2,3,4,7,8,9}
s2={3,4,5,6}
s1.symmetric_difference(s2) # comman element remove and arrange in orderd
# Out:
# {1, 2, 5, 6, 7, 8, 9}

# %%
txt="hello"
txt.upper()
# Out:
# 'HELLO'
